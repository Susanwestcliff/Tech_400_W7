# %%
import os
import re
import numpy as np
from collections import defaultdict
from math import log

# %%
# Preprocessing
def clean_text(text):
    return re.findall(r'\b\w+\b', text.lower())

# Load text files into a dictionary
def fetch_documents(directory_path):
    documents = {}
    for doc_file in os.listdir(directory_path):
        if doc_file.endswith('.txt'):
            with open(os.path.join(directory_path, doc_file), 'r') as f:
                documents[doc_file] = clean_text(f.read())
    return documents

# Loading query
def fetch_queries(query_path):
    with open(query_path, 'r') as f:
        return [line.strip() for line in f.readlines()]

# %%
# Calculate term frequencies and document frequencies
def calculate_frequencies(docs):
    total_docs = len(docs)
    term_in_docs = defaultdict(int)
    term_frequency = defaultdict(lambda: defaultdict(int))

    for document, terms in docs.items():
        unique_terms = set(terms)
        for term in terms:
            term_frequency[document][term] += 1
        for term in unique_terms:
            term_in_docs[term] += 1

    return term_frequency, term_in_docs, total_docs

# Compute BIM-based relevance scores
def get_relevance_score(query_terms, term_frequency, term_in_docs, total_docs):
    relevance_scores = {}
    for doc_name in term_frequency:
        probability_score = 1.0
        for term in query_terms:
            term_freq = term_frequency[doc_name].get(term, 0)
            doc_freq = term_in_docs.get(term, 0)
            prob_relevant = (term_freq + 1) / (sum(term_frequency[doc_name].values()) + len(term_in_docs))
            prob_non_relevant = (doc_freq + 1) / (total_docs - doc_freq + len(term_in_docs))
            probability_score *= (prob_relevant / prob_non_relevant)
        relevance_scores[doc_name] = probability_score
    return relevance_scores

# %%
# Core function to retrieve documents based on queries
def search_documents(directory_path, query_path):
    documents = fetch_documents(directory_path)
    query_list = fetch_queries(query_path)

    term_frequency, term_in_docs, total_docs = calculate_frequencies(documents)

    for query_text in query_list:
        query_words = clean_text(query_text)
        scores = get_relevance_score(query_words, term_frequency, term_in_docs, total_docs)
        sorted_docs = sorted(scores.items(), key=lambda item: item[1], reverse=True)
        print(f"Query: {query_text}")
        for doc_name, rel_score in sorted_docs:
            print(f"Document: {doc_name}, Score: {rel_score:.4f}")
        print()

# %%
# Calculate Average Precision (AP) for a single query
def calculate_average_precision(relevant_docs, ranked_docs):
    """
    Params:
      relevant_docs...A set of relevant document IDs for the query.
      ranked_docs.....A list of ranked document IDs for the query.

    Returns:
      Average Precision (float).
    """
    if not relevant_docs:
        return 0.0

    relevant_docs = set(relevant_docs)
    num_relevant = len(relevant_docs)

    score = 0.0
    num_hits = 0

    for i, (doc_id, _) in enumerate(ranked_docs):
        if doc_id in relevant_docs:
            num_hits += 1
            score += num_hits / (i + 1)  # Precision at each relevant doc position

    return score / num_relevant

# directory
doc_directory = '/content/drive/MyDrive/ tech400 Dataset and Query'
query_file = '/content/drive/MyDrive/query/final_query.txt'

search_documents(doc_directory, query_file)
# Out:
# Query: How to make beef fry
# Document: french_fries.txt, Score: 0.0158
# Document: egg_fired_rice.txt, Score: 0.0065
# Document: beef_fry.txt, Score: 0.0053
# Document: chicken_chilli.txt, Score: 0.0043
# Document: butter_chicken.txt, Score: 0.0017
# Document: beef_burger.txt, Score: 0.0016
# Document: egg_salad.txt, Score: 0.0016
# Document: lemonade.txt, Score: 0.0013
# Document: hummus.txt, Score: 0.0009
# Document: veg_momo.txt, Score: 0.0005
# Document: Mutton_gravy.txt, Score: 0.0005
# Document: eggless_choco_lava.txt, Score: 0.0004
# Document: virgin_mojito.txt, Score: 0.0003
# Document: chicken_biryani.txt, Score: 0.0003
# Document: cheese_cake.txt, Score: 0.0002
#
# Query: How to make butter chicken
# Document: butter_chicken.txt, Score: 1.2931
# Document: chicken_chilli.txt, Score: 0.0830
# Document: egg_fired_rice.txt, Score: 0.0038
# Document: chicken_biryani.txt, Score: 0.0030
# Document: french_fries.txt, Score: 0.0015
# Document: eggless_choco_lava.txt, Score: 0.0008
# Document: egg_salad.txt, Score: 0.0007
# Document: lemonade.txt, Score: 0.0006
# Document: virgin_mojito.txt, Score: 0.0005
# Document: cheese_cake.txt, Score: 0.0005
# Document: hummus.txt, Score: 0.0004
# Document: veg_momo.txt, Score: 0.0003
# Document: Mutton_gravy.txt, Score: 0.0002
# Document: beef_burger.txt, Score: 0.0002
# Document: beef_fry.txt, Score: 0.0001
#
# Query: How to make hummus
# Document: hummus.txt, Score: 0.1101
# Document: butter_chicken.txt, Score: 0.0329
# Document: egg_fired_rice.txt, Score: 0.0237
# Document: french_fries.txt, Score: 0.0235
# Document: egg_salad.txt, Score: 0.0185
# Document: lemonade.txt, Score: 0.0142
# Document: chicken_chilli.txt, Score: 0.0085
# Document: virgin_mojito.txt, Score: 0.0071
# Document: eggless_choco_lava.txt, Score: 0.0068
# Document: veg_momo.txt, Score: 0.0065
# Document: Mutton_gravy.txt, Score: 0.0056
# Document: chicken_biryani.txt, Score: 0.0043
# Document: beef_burger.txt, Score: 0.0035
# Document: cheese_cake.txt, Score: 0.0028
# Document: beef_fry.txt, Score: 0.0014
#
# Query: How to make chicken biryani
# Document: chicken_biryani.txt, Score: 0.1400
# Document: butter_chicken.txt, Score: 0.1215
# Document: chicken_chilli.txt, Score: 0.0624
# Document: egg_fired_rice.txt, Score: 0.0116
# Document: french_fries.txt, Score: 0.0045
# Document: egg_salad.txt, Score: 0.0022
# Document: lemonade.txt, Score: 0.0018
# Document: virgin_mojito.txt, Score: 0.0015
# Document: hummus.txt, Score: 0.0013
# Document: veg_momo.txt, Score: 0.0008
# Document: Mutton_gravy.txt, Score: 0.0006
# Document: eggless_choco_lava.txt, Score: 0.0006
# Document: beef_burger.txt, Score: 0.0005
# Document: cheese_cake.txt, Score: 0.0003
# Document: beef_fry.txt, Score: 0.0002
#
# Query: How to make chicken chilli
# Document: chicken_chilli.txt, Score: 2.4515
# Document: butter_chicken.txt, Score: 0.0809
# Document: egg_fired_rice.txt, Score: 0.0077
# Document: french_fries.txt, Score: 0.0030
# Document: chicken_biryani.txt, Score: 0.0030
# Document: egg_salad.txt, Score: 0.0015
# Document: Mutton_gravy.txt, Score: 0.0013
# Document: lemonade.txt, Score: 0.0012
# Document: virgin_mojito.txt, Score: 0.0010
# Document: hummus.txt, Score: 0.0009
# Document: veg_momo.txt, Score: 0.0005
# Document: eggless_choco_lava.txt, Score: 0.0004
# Document: beef_burger.txt, Score: 0.0003
# Document: cheese_cake.txt, Score: 0.0002
# Document: beef_fry.txt, Score: 0.0001
#
# Query: How to make lemonade
# Document: lemonade.txt, Score: 0.0708
# Document: butter_chicken.txt, Score: 0.0329
# Document: egg_fired_rice.txt, Score: 0.0237
# Document: french_fries.txt, Score: 0.0235
# Document: egg_salad.txt, Score: 0.0185
# Document: hummus.txt, Score: 0.0110
# Document: chicken_chilli.txt, Score: 0.0085
# Document: virgin_mojito.txt, Score: 0.0071
# Document: eggless_choco_lava.txt, Score: 0.0068
# Document: veg_momo.txt, Score: 0.0065
# Document: Mutton_gravy.txt, Score: 0.0056
# Document: chicken_biryani.txt, Score: 0.0043
# Document: beef_burger.txt, Score: 0.0035
# Document: cheese_cake.txt, Score: 0.0028
# Document: beef_fry.txt, Score: 0.0014
#
# Query: How to make egg fried rice
# Document: egg_fired_rice.txt, Score: 1.0324
# Document: chicken_chilli.txt, Score: 0.0024
# Document: chicken_biryani.txt, Score: 0.0016
# Document: egg_salad.txt, Score: 0.0004
# Document: butter_chicken.txt, Score: 0.0004
# Document: lemonade.txt, Score: 0.0001
# Document: french_fries.txt, Score: 0.0001
# Document: veg_momo.txt, Score: 0.0001
# Document: beef_burger.txt, Score: 0.0001
# Document: hummus.txt, Score: 0.0001
# Document: Mutton_gravy.txt, Score: 0.0001
# Document: eggless_choco_lava.txt, Score: 0.0000
# Document: beef_fry.txt, Score: 0.0000
# Document: cheese_cake.txt, Score: 0.0000
# Document: virgin_mojito.txt, Score: 0.0000
#
# Query: How to make egg salad
# Document: egg_salad.txt, Score: 0.0415
# Document: egg_fired_rice.txt, Score: 0.0306
# Document: butter_chicken.txt, Score: 0.0019
# Document: french_fries.txt, Score: 0.0018
# Document: lemonade.txt, Score: 0.0014
# Document: virgin_mojito.txt, Score: 0.0012
# Document: chicken_chilli.txt, Score: 0.0011
# Document: beef_burger.txt, Score: 0.0011
# Document: hummus.txt, Score: 0.0010
# Document: eggless_choco_lava.txt, Score: 0.0009
# Document: veg_momo.txt, Score: 0.0006
# Document: Mutton_gravy.txt, Score: 0.0005
# Document: chicken_biryani.txt, Score: 0.0003
# Document: cheese_cake.txt, Score: 0.0003
# Document: beef_fry.txt, Score: 0.0001
#
# Query: How to make eggless choco lava
# Document: eggless_choco_lava.txt, Score: 13.4355
# Document: egg_salad.txt, Score: 0.0033
# Document: lemonade.txt, Score: 0.0028
# Document: egg_fired_rice.txt, Score: 0.0028
# Document: french_fries.txt, Score: 0.0027
# Document: butter_chicken.txt, Score: 0.0023
# Document: hummus.txt, Score: 0.0020
# Document: veg_momo.txt, Score: 0.0011
# Document: Mutton_gravy.txt, Score: 0.0009
# Document: beef_burger.txt, Score: 0.0007
# Document: chicken_chilli.txt, Score: 0.0007
# Document: cheese_cake.txt, Score: 0.0005
# Document: chicken_biryani.txt, Score: 0.0005
# Document: virgin_mojito.txt, Score: 0.0004
# Document: beef_fry.txt, Score: 0.0003
#
# Query: How to make french fries
# Document: french_fries.txt, Score: 5.2412
# Document: butter_chicken.txt, Score: 0.0087
# Document: egg_fired_rice.txt, Score: 0.0081
# Document: egg_salad.txt, Score: 0.0078
# Document: lemonade.txt, Score: 0.0063
# Document: hummus.txt, Score: 0.0047
# Document: veg_momo.txt, Score: 0.0027
# Document: chicken_chilli.txt, Score: 0.0024
# Document: Mutton_gravy.txt, Score: 0.0023
# Document: eggless_choco_lava.txt, Score: 0.0020
# Document: virgin_mojito.txt, Score: 0.0018
# Document: beef_burger.txt, Score: 0.0016
# Document: chicken_biryani.txt, Score: 0.0014
# Document: cheese_cake.txt, Score: 0.0012
# Document: beef_fry.txt, Score: 0.0006
#
# Query: How to make mutton gravy
# Document: Mutton_gravy.txt, Score: 0.0309
# Document: chicken_chilli.txt, Score: 0.0125
# Document: butter_chicken.txt, Score: 0.0104
# Document: egg_fired_rice.txt, Score: 0.0032
# Document: french_fries.txt, Score: 0.0032
# Document: egg_salad.txt, Score: 0.0031
# Document: lemonade.txt, Score: 0.0025
# Document: hummus.txt, Score: 0.0019
# Document: veg_momo.txt, Score: 0.0011
# Document: beef_fry.txt, Score: 0.0010
# Document: eggless_choco_lava.txt, Score: 0.0008
# Document: virgin_mojito.txt, Score: 0.0007
# Document: beef_burger.txt, Score: 0.0006
# Document: chicken_biryani.txt, Score: 0.0006
# Document: cheese_cake.txt, Score: 0.0005
#
# Query: How to make cheese cake
# Document: eggless_choco_lava.txt, Score: 0.0739
# Document: butter_chicken.txt, Score: 0.0058
# Document: egg_fired_rice.txt, Score: 0.0054
# Document: french_fries.txt, Score: 0.0053
# Document: egg_salad.txt, Score: 0.0052
# Document: lemonade.txt, Score: 0.0042
# Document: beef_burger.txt, Score: 0.0032
# Document: hummus.txt, Score: 0.0031
# Document: cheese_cake.txt, Score: 0.0024
# Document: veg_momo.txt, Score: 0.0018
# Document: chicken_chilli.txt, Score: 0.0016
# Document: Mutton_gravy.txt, Score: 0.0015
# Document: virgin_mojito.txt, Score: 0.0012
# Document: chicken_biryani.txt, Score: 0.0010
# Document: beef_fry.txt, Score: 0.0004
#
# Query: How to make beef burger
# Document: egg_fired_rice.txt, Score: 0.0081
# Document: beef_burger.txt, Score: 0.0079
# Document: butter_chicken.txt, Score: 0.0043
# Document: french_fries.txt, Score: 0.0040
# Document: egg_salad.txt, Score: 0.0039
# Document: beef_fry.txt, Score: 0.0033
# Document: lemonade.txt, Score: 0.0031
# Document: hummus.txt, Score: 0.0023
# Document: veg_momo.txt, Score: 0.0013
# Document: chicken_chilli.txt, Score: 0.0012
# Document: Mutton_gravy.txt, Score: 0.0011
# Document: eggless_choco_lava.txt, Score: 0.0010
# Document: virgin_mojito.txt, Score: 0.0009
# Document: chicken_biryani.txt, Score: 0.0007
# Document: cheese_cake.txt, Score: 0.0006
#
# Query: How to make veg momo
# Document: veg_momo.txt, Score: 0.0483
# Document: butter_chicken.txt, Score: 0.0174
# Document: egg_fired_rice.txt, Score: 0.0162
# Document: french_fries.txt, Score: 0.0159
# Document: egg_salad.txt, Score: 0.0156
# Document: lemonade.txt, Score: 0.0126
# Document: hummus.txt, Score: 0.0094
# Document: chicken_chilli.txt, Score: 0.0048
# Document: Mutton_gravy.txt, Score: 0.0046
# Document: eggless_choco_lava.txt, Score: 0.0040
# Document: virgin_mojito.txt, Score: 0.0035
# Document: beef_burger.txt, Score: 0.0032
# Document: chicken_biryani.txt, Score: 0.0029
# Document: cheese_cake.txt, Score: 0.0025
# Document: beef_fry.txt, Score: 0.0012
#
# Query: How to make virgin mojito
# Document: virgin_mojito.txt, Score: 0.0893
# Document: hummus.txt, Score: 0.0093
# Document: butter_chicken.txt, Score: 0.0087
# Document: egg_fired_rice.txt, Score: 0.0081
# Document: french_fries.txt, Score: 0.0079
# Document: egg_salad.txt, Score: 0.0078
# Document: lemonade.txt, Score: 0.0063
# Document: veg_momo.txt, Score: 0.0027
# Document: chicken_chilli.txt, Score: 0.0024
# Document: Mutton_gravy.txt, Score: 0.0023
# Document: eggless_choco_lava.txt, Score: 0.0020
# Document: beef_burger.txt, Score: 0.0016
# Document: chicken_biryani.txt, Score: 0.0014
# Document: cheese_cake.txt, Score: 0.0012
# Document: beef_fry.txt, Score: 0.0006
